# %% [markdown]
# # **Custom object training with YOLOv3 and Darknet**
#
# The phrase "You Only Look Once" is referred to as YOLO.
# This method detects and recognizes various objects in images (in real-time).
# YOLO performs object detection as a regression problem and outputs the class probabilities of the detected photos.
#
#
# Convolutional neural networks (CNN) are used by the YOLO method to recognize items instantly.
# As the name implies, the algorithm only needs one forward propagation through a neural network to detect objects.
#
#
# As a result, a single algorithm run is used to do prediction throughout the entire image.
# Simultaneously, several class probabilities and bounding boxes are predicted using CNN.
#
#
# There are numerous variations of the YOLO algorithm. One of them is
# **YOLOv3**.

# %% [markdown]
# # **Step 1**
# ## Enabling and testing the GPU
#
# The notebook's GPUs must first be enabled:
#
# - Select Notebook Settings under Edit.
# - choose GPU using the Hardware Accelerator drop-down
#
# Next, we'll check if Tensorflow can connect to the GPU: By executing the following code, you may quickly determine whether the GPU is enabled.

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Thu Dec 15 04:51:18 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P0    28W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # **Step 2**
# Mounting the Drive to store and load files.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Let's make the required files and directories for training with custom objects.
#
#
# 1. **custom_data/images**
# 2. **custom_data/custom.names**
# 3. **custom_data/train.txt**
# 4. **custom_data/test.txt**
# 5. **custom_data/backup**
# 6. **custom_data/detector.data**
# 7. **custom_data/cfg**

# %% [markdown]
# # **Step 3**
# ## *Creating Image Directory*
# We will train our model to recognise pistols in this project, thus we must gather the images and its annotaions and save them in the ***custom data/images*** directory.

# %% [markdown]
# ## Unzip Files
# * Your Google Drive file location that you wish to unzip is the first path in the cell below.
# * Where you wish to extract the zip file from Google Drive as shown by the second path in the cell below.
#
#
# In our case text files should be saved in **custom_data/images** directory. For e.g. **image1.jpg** should have a text file **image1.txt**.

# %%
# !unzip "/content/gdrive/MyDrive/custom_data/zip/images.zip" -d "/content/gdrive/MyDrive/custom_data"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1449).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1449).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (145).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (145).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1450).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1450).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1451).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1451).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1452).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1452).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1453).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1453).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1454).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1454).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1455).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1455).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1456).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1456).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1457).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1457).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1458).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1458).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1459).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1459).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (146).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (146).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1460).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1460).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1461).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1461).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1462).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1462).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1463).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1463).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1464).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1464).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1465).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1465).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1466).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1466).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1467).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1467).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1468).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1468).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1469).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1469).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (147).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (147).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1470).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1470).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1471).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1471).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1472).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1472).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1473).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1473).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1474).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1474).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1475).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1475).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1476).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1476).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1477).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1477).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1478).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1478).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1479).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1479).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (148).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (148).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1480).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1480).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1481).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1481).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1482).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1482).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1483).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1483).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1484).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1484).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1485).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1485).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1486).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1486).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1487).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1487).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1488).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1488).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1489).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1489).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (149).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (149).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1490).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1490).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1491).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1491).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1492).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1492).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1493).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1493).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1494).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1494).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1495).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1495).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1496).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1496).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1497).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1497).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1498).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1498).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1499).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1499).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (15).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (15).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (150).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (150).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1500).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1500).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1501).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1501).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1502).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1502).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1503).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1503).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1504).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1504).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1505).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1505).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1506).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1506).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1507).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1507).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1508).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1508).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1509).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1509).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (151).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (151).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1510).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1510).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1511).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1511).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1512).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1512).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1513).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1513).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1514).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1514).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1515).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1515).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1516).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1516).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1517).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1517).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1518).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1518).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1519).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1519).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (152).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (152).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1520).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1520).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1521).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1521).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1522).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1522).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1523).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1523).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1524).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1524).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1525).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1525).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1526).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1526).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1527).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1527).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1528).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1528).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1529).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1529).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (153).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (153).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1530).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1530).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1531).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1531).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1532).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1532).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1533).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1533).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1534).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1534).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1535).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1535).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1536).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1536).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1537).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1537).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1538).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1538).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1539).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1539).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (154).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (154).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1540).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1540).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1541).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1541).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1542).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1542).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1543).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1543).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1544).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1544).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1545).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1545).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1546).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1546).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1547).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1547).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1548).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1548).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1549).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1549).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (155).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (155).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1550).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1550).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1551).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1551).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1552).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1552).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1553).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1553).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1554).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1554).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1555).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1555).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1556).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1556).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1557).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1557).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1558).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1558).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1559).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1559).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (156).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (156).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1560).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1560).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1561).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1561).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1562).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1562).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1563).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1563).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1564).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1564).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1565).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1565).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1566).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1566).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1567).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1567).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1568).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1568).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1569).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1569).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (157).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (157).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1570).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1570).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1571).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1571).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1572).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1572).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1573).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1573).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1574).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1574).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1575).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1575).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1576).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1576).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1577).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1577).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1578).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1578).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1579).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1579).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (158).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (158).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1580).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1580).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1581).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1581).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1582).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1582).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1583).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1583).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1584).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1584).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1585).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1585).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1586).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1586).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1587).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1587).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1588).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1588).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1589).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1589).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (159).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (159).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1590).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1590).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1591).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1591).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1592).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1592).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1593).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1593).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1594).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1594).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1595).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1595).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1596).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1596).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1597).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1597).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1598).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1598).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1599).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1599).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (16).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (16).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (160).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (160).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1600).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1600).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1601).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1601).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1602).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1602).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1603).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1603).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1604).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1604).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1605).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1605).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1606).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1606).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1607).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1607).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1608).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1608).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1609).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1609).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (161).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (161).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1610).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1610).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1611).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1611).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1612).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1612).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1613).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1613).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1614).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1614).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1615).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1615).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1616).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1616).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1617).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1617).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1618).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1618).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1619).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1619).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (162).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (162).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1620).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1620).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1621).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1621).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1622).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1622).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1623).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1623).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1624).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1624).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1625).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1625).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1626).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1626).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1627).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1627).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1628).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1628).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1629).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1629).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (163).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (163).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1630).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1630).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1631).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1631).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1632).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1632).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1633).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1633).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1634).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1634).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1635).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1635).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1636).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1636).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1637).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1637).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1638).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1638).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1639).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1639).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (164).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (164).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1640).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1640).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1641).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1641).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1642).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1642).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1643).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1643).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1644).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1644).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1645).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1645).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1646).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1646).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1647).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1647).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1648).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1648).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1649).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1649).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (165).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (165).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1650).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1650).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1651).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1651).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1652).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1652).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1653).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1653).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1654).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1654).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1655).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1655).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1656).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1656).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1657).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1657).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1658).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1658).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1659).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1659).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (166).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (166).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1660).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1660).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1661).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1661).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1662).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1662).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1663).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1663).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1664).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1664).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1665).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1665).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1666).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1666).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1667).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1667).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1668).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1668).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1669).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1669).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (167).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (167).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1670).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1670).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1671).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1671).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1672).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1672).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1673).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1673).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1674).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1674).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1675).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1675).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1676).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1676).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1677).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1677).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1678).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1678).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1679).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1679).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (168).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (168).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1680).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1680).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1681).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1681).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1682).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1682).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1683).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1683).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1684).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1684).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1685).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1685).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1686).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1686).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1687).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1687).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1688).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1688).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1689).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1689).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (169).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (169).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1690).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1690).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1691).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1691).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1692).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1692).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1693).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1693).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1694).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1694).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1695).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1695).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1696).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1696).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1697).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1697).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1698).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1698).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1699).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1699).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (17).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (17).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (170).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (170).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1700).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1700).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1701).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1701).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1702).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1702).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1703).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1703).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1704).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1704).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1705).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1705).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1706).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1706).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1707).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1707).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1708).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1708).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1709).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1709).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (171).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (171).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1710).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1710).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1711).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1711).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1712).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1712).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1713).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1713).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1714).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1714).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1715).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1715).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1716).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1716).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1717).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1717).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1718).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1718).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1719).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1719).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (172).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (172).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1720).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1720).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1721).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1721).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1722).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1722).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1723).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1723).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1724).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1724).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1725).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1725).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1726).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1726).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1727).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1727).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1728).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1728).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1729).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1729).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (173).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (173).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1730).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1730).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1731).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1731).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1732).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1732).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1733).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1733).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1734).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1734).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1735).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1735).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1736).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (1736).txt
# ...
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (901).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (901).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (902).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (902).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (903).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (903).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (904).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (904).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (905).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (905).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (906).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (906).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (907).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (907).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (908).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (908).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (909).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (909).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (91).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (91).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (910).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (910).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (911).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (911).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (912).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (912).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (913).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (913).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (914).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (914).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (915).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (915).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (916).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (916).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (917).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (917).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (918).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (918).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (919).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (919).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (92).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (92).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (920).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (920).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (921).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (921).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (922).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (922).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (923).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (923).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (924).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (924).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (925).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (925).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (926).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (926).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (927).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (927).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (928).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (928).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (929).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (929).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (93).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (93).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (930).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (930).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (931).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (931).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (932).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (932).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (933).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (933).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (934).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (934).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (935).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (935).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (936).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (936).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (937).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (937).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (938).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (938).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (939).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (939).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (94).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (94).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (940).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (940).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (941).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (941).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (942).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (942).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (943).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (943).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (944).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (944).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (945).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (945).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (946).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (946).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (947).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (947).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (948).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (948).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (949).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (949).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (95).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (95).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (950).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (950).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (951).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (951).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (952).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (952).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (953).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (953).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (954).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (954).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (955).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (955).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (956).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (956).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (957).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (957).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (958).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (958).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (959).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (959).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (96).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (96).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (960).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (960).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (961).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (961).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (962).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (962).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (963).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (963).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (964).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (964).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (965).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (965).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (966).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (966).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (967).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (967).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (968).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (968).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (969).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (969).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (97).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (97).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (970).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (970).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (971).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (971).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (972).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (972).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (973).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (973).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (974).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (974).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (975).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (975).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (976).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (976).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (977).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (977).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (978).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (978).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (979).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (979).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (98).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (98).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (980).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (980).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (981).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (981).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (982).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (982).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (983).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (983).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (984).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (984).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (985).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (985).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (986).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (986).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (987).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (987).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (988).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (988).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (989).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (989).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (99).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (99).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (990).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (990).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (991).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (991).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (992).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (992).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (993).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (993).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (994).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (994).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (995).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (995).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (996).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (996).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (997).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (997).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (998).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (998).txt
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (999).jpg
#   inflating: /content/gdrive/MyDrive/custom_data/images/armas (999).txt

# %% [markdown]
# # **Step 4**
# ## *Creating Custom.names file*
# Labels of our objects should be saved in **custom_data/custom.names** file, each line in the file corresponds to an object. In our case since we have only one object class, the file should contain the following.

# %% [markdown]
# ![Screenshot from 2022-10-19 19-40-25.png](data:image/png;base64,...)

# %% [markdown]
# # **Step 5**
# ## *Creating Train and Test files*
# The annotated photos can then be randomly split into train and test sets in a **80:20** ratio.
#
# **custom data/train.txt** The location of the train dataset should be listed in each file row.
#
# **custom data/test.txt** The location of the test dataset should be listed in each file row.

# %% [markdown]
# ![Screenshot from 2022-12-13 11-59-16.png](data:image/png;base64,...)

# %% [markdown]
# # **Step 6**
# ## *Creating Backup directory*
# Creating backup directory for storing weights of the trained model.

# %% [markdown]
# # **Step 7**
# ## *Creating YOLO data file*
# Make a file called "detector.data" in the "custom data" directory that contains details about the train and test data sets.

# %% [markdown]
# ![Screenshot from 2022-10-19 19-49-20.png](data:image/png;base64,...)

# %% [markdown]
# # **Step 8**
# ## *Cloning Directory to use Darknet*
# Darknet, an open source neural network framework, will be used to train the detector. Download and create a dark network

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15502, done.
# remote: Total 15502 (delta 0), reused 0 (delta 0), pack-reused 15502
# Receiving objects: 100% (15502/15502), 14.17 MiB | 20.43 MiB/s, done.
# Resolving deltas: 100% (10405/10405), done.

# %%
# Change current working directory to Darknet
# %cd darknet
# Out:
# /content/darknet

# %% [markdown]
# ### Change makefile to have GPU and OPENCV enabled, and other parameters for faster computation.

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile 
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile

# %%
# Make file
"/content/darknet/Makefile"
# Out:
# '/content/darknet/Makefile'

# %% [markdown]
# ### Model Compilation

# %%
# compiling the model
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ./src/image_opencv.cpp:1150:10: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#           if (iteration_old != 0){
#           ^~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1444:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ./src/image_opencv.cpp:1420:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#      int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1424:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#      int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1428:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#      int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1431:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#      int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#          ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:511:113: warning: format ‘%zu’ expects argument of type ‘size_t’, but argument 3 has type ‘int’ [-Wformat=]
#                  sprintf(head, "--mjpegstream\r\nContent-Type: image/jpeg\r\nContent-Length: %zu\r\n\r\n", outlen);
#                                                                                                                  ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:867:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < v.size(); ++i) {
#                          ~~^~~~~~~~~~
# ./src/http_stream.cpp:875:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#                           ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:894:31: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#                          ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:930:28: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#          ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2044:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2043:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1061:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#      while (c = *str++)
#             ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:230:20: warning: comparison between ‘cudaError_t {aka enum cudaError}’ and ‘enum <anonymous>’ [-Wenum-compare]
#          if (status != CUDNN_STATUS_SUCCESS)
#                     ^~
# ./src/dark_cuda.c: In function ‘cublas_check_error_extended’:
# ./src/dark_cuda.c:264:18: warning: comparison between ‘cudaError_t {aka enum cudaError}’ and ‘enum cudaError_enum’ [-Wenum-compare]
#        if (status != CUDA_SUCCESS)
#                   ^~
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:395:40: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                       ~~^
#                                       %Ilu
#              size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#              ~~~~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:395:64: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                               ~~^
#                                                               %Ilu
# ./src/dark_cuda.c:395:82: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                                                 ~~^
#                                                                                 %Ilu
# ./src/dark_cuda.c:405:37: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                                     ~^
#                                     %ld
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:426:43: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                                           ~^
#                                           %ld
# ./src/dark_cuda.c:441:64: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                                                                ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                                %ld
# ./src/dark_cuda.c:447:63: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                                                               ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                               %ld
# At top level:
# ./src/dark_cuda.c:287:23: warning: ‘switchBlasHandle’ defined but not used [-Wunused-variable]
#  static cublasHandle_t switchBlasHandle[16];
#                        ^~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:286:12: warning: ‘switchBlasInit’ defined but not used [-Wunused-variable]
#  static int switchBlasInit[16] = { 0 };
#             ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1342:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^~~~~~~~~
# ./src/blas.c: In function ‘find_sim’:
# ./src/blas.c:597:59: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                           ~^
#                                                           %ld
# ./src/blas.c:597:67: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                   ~^
#                                                                   %ld
# ./src/blas.c:597:75: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                           ~^
#                                                                           %ld
# ./src/blas.c: In function ‘find_P_constrastive’:
# ./src/blas.c:611:68: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                    ~^
#                                                                    %ld
# ./src/blas.c:611:76: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                            ~^
#                                                                            %ld
# ./src/blas.c:611:84: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                                    ~^
#                                                                                    %ld
# ./src/blas.c: In function ‘P_constrastive_f’:
# ./src/blas.c:651:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:651:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# ./src/blas.c: In function ‘P_constrastive’:
# ./src/blas.c:785:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:785:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘make_contrastive_layer’:
# ./src/softmax_layer.c:203:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 9 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#      fprintf(stderr, "contrastive %4d x%4d x%4d x emb_size %4d x batch: %4d  classes = %4d, step = %4d \n", w, h, l.n, l.embedding_size, batch, l.classes, step);
#                                                                                                    ~~^
#                                                                                                    %4ld
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:244:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#                      float max_truth = 0;
#                            ^~~~~~~~~
# ./src/softmax_layer.c:423:71: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#              printf(" Error: too large number of bboxes: contr_size = %d > max_contr_size  = %d \n", contr_size, max_contr_size);
#                                                                       ~^
#                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1297:24: warning: unused variable ‘x’ [-Wunused-variable]
#                  int k, x, y;
#                         ^
# ./src/data.c:1090:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#      float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#                                            ^~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘train_network_waitkey’:
# ./src/network.c:435:13: warning: unused variable ‘ema_period’ [-Wunused-variable]
#          int ema_period = (net.max_batches - ema_start_point - 1000) * (1.0 - net.ema_alpha);
#              ^~~~~~~~~~
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:660:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4915:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1777:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4915:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/parser.c: In function ‘save_implicit_weights’:
# ./src/parser.c:1909:9: warning: unused variable ‘i’ [-Wunused-variable]
#      int i;
#          ^
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:438:29: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#          classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#          ~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:0:
# /usr/include/stdlib.h:541:14: note: in a call to allocation function ‘calloc’ declared here
#  extern void *calloc (size_t __nmemb, size_t __size)
#               ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#      switch(iou_kind) {
#      ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘train_detector’:
# ./src/detector.c:395:72: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#              (iteration >= (iter_save + 1000) || iteration % 1000 == 0) && net.max_batches < 10000)
#              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:588:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:709:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^~~~
# ./src/detector.c:707:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1326:24: warning: variable ‘cur_prob’ set but not used [-Wunused-but-set-variable]
#                  double cur_prob = 0;
#                         ^~~~~~~~
# ./src/detector.c:1347:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1346:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1890:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#              float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#                    ^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:208:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#      if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#                                                    ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:146:9: warning: unused variable ‘count’ [-Wunused-variable]
#      int count = 0;
#          ^~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:855:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1287:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                                  ^~~~~~~~~~~
# ./src/classifier.c:1287:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                      ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/representation_layer.c -o obj/representation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:101:15: warning: unused variable ‘l’ [-Wunused-variable]
#          layer l = net.layers[net.n - 1];
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:63:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#      int old_h = l->h;
#          ^~~~~
# ./src/region_layer.c:62:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#      int old_w = l->w;
#          ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:68:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4915:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:75:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4915:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:106:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4915:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:115:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
# ...
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/im2col_kernels.cu(1354): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1354): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1354): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1354): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1354): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning: unrecognized #pragma in device code
#
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu: In function ‘void backward_shortcut_multilayer_gpu(int, int, int, int*, float**, float*, float*, float*, float*, int, float*, float**, WEIGHTS_NORMALIZATION_T)’:
# ./src/blas_kernels.cu:1130:5: warning: variable ‘step’ set but not used [-Wunused-but-set-variable]
#      int step = 0;
#      ^~~~
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/network_kernels.cu(379): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(379): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(379): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(379): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(379): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu: In function ‘float train_network_datum_gpu(network, float*, float*)’:
# ./src/network_kernels.cu:379:7: warning: variable ‘l’ set but not used [-Wunused-but-set-variable]
#          layer l = net.layers[net.n - 1];
#        ^
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/representation_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %% [markdown]
# # **Step 9**
# ## *Making changes in the yolo Configuration file*
# We can choose the YOLOv3 configuration file based on the performance that is necessary. **Yolov3.cfg** will be used in this example. The file from **darknet/cfg/yolov3.cfg** can be copied to **custom data/cfg/yolov3-custom.cfg**.
#
# _
#
# The neural network weights are iteratively adjusted as the images are trained. We may use large training sets, making it resource-intensive to update the weights for the full training set in a single cycle. The **batch** parameter is specified to utilise a small set of images to iteratively update the weights. It is initially set at 64.
#
# _
#
# The parameter **max batches** determines the maximum number of iterations for which our network should be trained. You can calculate its value with the formula **max_batches = classes*2000**, i.e. **2000** for a single class, and modify the line steps to **80%** and **90%** of max batches, which is **1600,1800**.
#
# when the model reaches to **2000 epochs** during training for 1 class, it will stop the training, because we defined that in our max_batches parameter, if you want to train your model beyound from that, increase the value of max_batches, and also increase its steps, like when you change the value to **max batches=6000**, modify the line steps to **80%** and **90%** of max batches, i.e. steps=4800,5400.
#
# --
#
# The **classes** and **filters** parameters of the [yolo] and [convolutional] layers immediately preceding the [yolo] layers must be updated.
#
#
# Since there is just one class in this project (Pistol), we will update the class parameter in the [yolo] layers to **1** at lines **610, 696, and 783**.
#
# The **filters** parameter will also need to be updated based on the classes count: **filters=(classes + 5) * 3**. We should set **filters=18** for a single class at **line numbers: 603, 689, 776**.
#
# Custom data/cfg/yolov3-custom.cfg contains all configuration changes.

# %% [markdown]
# # **Step 10**
# ## *Downloading Pre-trained weights*
# To train our object detector, we can use the pre-trained weights that have already been trained on a large data sets. The pre-trained weights are available [here](https://pjreddie.com/media/files/darknet53.conv.74), and they can be downloaded to the root directory.

# %%
# Download weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2022-12-14 06:46:53--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  56.6MB/s    in 2.7s
#
# 2022-12-14 06:46:56 (56.6 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# # **Step 11**
# ## *Training the model*
# As soon as we have all the necessary files and annotated photographs, we can begin our training.
# Up till the loss reaches a predefined level, we can keep training. Weights for the custom detector are initially saved once every 100 iterations until 1,000 iterations, after which they are saved once every 10,000 iterations by default.
#
# We can do detection using the generated weights after the training is finished.

# %%
# !./darknet detector train /content/gdrive/MyDrive/custom_data/detector.data /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 11020 (11020), cuDNN: 8.1.1, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# yolov3-custom
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv     18       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  18 0.006 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv     18       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  18 0.012 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#   98 route  97 36 	                           ->   52 x  52 x 384
#   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
#  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  105 conv     18       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x  18 0.025 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 65.304
# avg_outputs = 516723
#  Allocate additional workspace_size = 149.82 MB
# Loading weights from darknet53.conv.74...
#  seen 64, trained: 0 K-images (0 Kilo-batches_64)
# Done! Loaded 75 layers from weights-file
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# Resizing, random_coef = 1.40
#
#  608 x 608
#  Create 6 permanent cpu-threads
#  try to allocate additional workspace_size = 144.50 MB
#  CUDA allocate done!
# Loaded: 0.000047 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.343230), count: 4, class_loss = 308.528717, iou_loss = 4.263947, total_loss = 312.792664
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1178.845581, iou_loss = 0.000000, total_loss = 1178.845581
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5309.653809, iou_loss = 0.000000, total_loss = 5309.653809
#  total_bbox = 4, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.467059), count: 4, class_loss = 308.912354, iou_loss = 1.377014, total_loss = 310.289368
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.177793), count: 1, class_loss = 1183.032837, iou_loss = 1.626221, total_loss = 1184.659058
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5331.627930, iou_loss = 0.000000, total_loss = 5331.627930
#  total_bbox = 9, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.462185), count: 3, class_loss = 308.761261, iou_loss = 0.751251, total_loss = 309.512512
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.093609), count: 1, class_loss = 1178.330566, iou_loss = 1.943237, total_loss = 1180.273804
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5287.413086, iou_loss = 0.000000, total_loss = 5287.413086
#  total_bbox = 13, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.367143), count: 3, class_loss = 308.887482, iou_loss = 1.084137, total_loss = 309.971619
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.085969), count: 1, class_loss = 1185.200073, iou_loss = 1.713379, total_loss = 1186.913452
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5344.528809, iou_loss = 0.000000, total_loss = 5344.528809
#  total_bbox = 17, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.275244), count: 4, class_loss = 310.303192, iou_loss = 1.678864, total_loss = 311.982056
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1180.602539, iou_loss = 0.000000, total_loss = 1180.602539
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5306.476562, iou_loss = 0.000000, total_loss = 5306.476562
#  total_bbox = 21, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.331626), count: 3, class_loss = 309.343750, iou_loss = 1.160217, total_loss = 310.503967
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.287618), count: 1, class_loss = 1182.581055, iou_loss = 0.571167, total_loss = 1183.152222
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5339.308594, iou_loss = 0.000000, total_loss = 5339.308594
#  total_bbox = 25, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.313727), count: 3, class_loss = 309.145203, iou_loss = 2.469269, total_loss = 311.614471
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.081174), count: 1, class_loss = 1179.215698, iou_loss = 2.756958, total_loss = 1181.972656
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5330.476074, iou_loss = 0.000000, total_loss = 5330.476074
#  total_bbox = 29, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.465173), count: 4, class_loss = 309.810028, iou_loss = 1.334259, total_loss = 311.144287
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1177.277710, iou_loss = 0.000000, total_loss = 1177.277710
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5322.963379, iou_loss = 0.000000, total_loss = 5322.963379
#  total_bbox = 33, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.464859), count: 4, class_loss = 309.220734, iou_loss = 1.031067, total_loss = 310.251801
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1176.766846, iou_loss = 0.000000, total_loss = 1176.766846
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5296.875000, iou_loss = 0.000000, total_loss = 5296.875000
#  total_bbox = 37, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.381726), count: 4, class_loss = 308.620728, iou_loss = 2.124725, total_loss = 310.745453
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1176.846436, iou_loss = 0.000000, total_loss = 1176.846436
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5294.902832, iou_loss = 0.000000, total_loss = 5294.902832
#  total_bbox = 41, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.416703), count: 3, class_loss = 308.069550, iou_loss = 0.463776, total_loss = 308.533325
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.598064), count: 1, class_loss = 1177.160278, iou_loss = 0.245239, total_loss = 1177.405518
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5330.370117, iou_loss = 0.000000, total_loss = 5330.370117
#  total_bbox = 45, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.207273), count: 4, class_loss = 309.584869, iou_loss = 1.432251, total_loss = 311.017120
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1180.456299, iou_loss = 0.000000, total_loss = 1180.456299
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5325.579590, iou_loss = 0.000000, total_loss = 5325.579590
#  total_bbox = 49, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.278980), count: 4, class_loss = 309.418091, iou_loss = 1.687775, total_loss = 311.105865
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1182.090942, iou_loss = 0.000000, total_loss = 1182.090942
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5349.486328, iou_loss = 0.000000, total_loss = 5349.486328
#  total_bbox = 53, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.526748), count: 4, class_loss = 310.252472, iou_loss = 0.911530, total_loss = 311.164001
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1180.205688, iou_loss = 0.000000, total_loss = 1180.205688
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5313.769531, iou_loss = 0.000000, total_loss = 5313.769531
#  total_bbox = 57, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.531805), count: 4, class_loss = 309.224213, iou_loss = 1.041626, total_loss = 310.265839
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1178.671875, iou_loss = 0.000000, total_loss = 1178.671875
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5320.687012, iou_loss = 0.000000, total_loss = 5320.687012
#  total_bbox = 61, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.266856), count: 3, class_loss = 309.803650, iou_loss = 1.379120, total_loss = 311.182770
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.348811), count: 2, class_loss = 1181.372314, iou_loss = 1.459595, total_loss = 1182.831909
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5310.400879, iou_loss = 0.000000, total_loss = 5310.400879
#  total_bbox = 66, rewritten_bbox = 0.000000 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
#
#  1: 2270.324463, 2270.324463 avg loss, 0.000000 rate, 9.591851 seconds, 64 images, -1.000000 hours left
# Loaded: 0.000077 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.302617), count: 4, class_loss = 308.407440, iou_loss = 2.761658, total_loss = 311.169098
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1181.815308, iou_loss = 0.000000, total_loss = 1181.815308
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5339.908203, iou_loss = 0.000000, total_loss = 5339.908203
#  total_bbox = 70, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.372097), count: 4, class_loss = 309.745514, iou_loss = 1.603424, total_loss = 311.348938
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1182.834717, iou_loss = 0.000000, total_loss = 1182.834717
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5339.442383, iou_loss = 0.000000, total_loss = 5339.442383
#  total_bbox = 74, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.254555), count: 3, class_loss = 309.602051, iou_loss = 1.948303, total_loss = 311.550354
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1180.652588, iou_loss = 0.000000, total_loss = 1180.652588
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5336.572754, iou_loss = 0.000000, total_loss = 5336.572754
#  total_bbox = 77, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.343117), count: 4, class_loss = 310.575745, iou_loss = 1.063507, total_loss = 311.639252
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1179.217773, iou_loss = 0.000000, total_loss = 1179.217773
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5264.111816, iou_loss = 0.000000, total_loss = 5264.111816
#  total_bbox = 81, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.659335), count: 4, class_loss = 309.315857, iou_loss = 0.398651, total_loss = 309.714508
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1176.388916, iou_loss = 0.000000, total_loss = 1176.388916
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5270.697754, iou_loss = 0.000000, total_loss = 5270.697754
#  total_bbox = 85, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.315610), count: 4, class_loss = 309.504456, iou_loss = 2.216278, total_loss = 311.720734
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1180.335938, iou_loss = 0.000000, total_loss = 1180.335938
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5333.974609, iou_loss = 0.000000, total_loss = 5333.974609
#  total_bbox = 89, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.282809), count: 4, class_loss = 308.309906, iou_loss = 2.521881, total_loss = 310.831787
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1174.159424, iou_loss = 0.000000, total_loss = 1174.159424
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5239.007812, iou_loss = 0.000000, total_loss = 5239.007812
#  total_bbox = 93, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.342965), count: 5, class_loss = 308.699402, iou_loss = 2.645752, total_loss = 311.345154
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1182.651367, iou_loss = 0.000000, total_loss = 1182.651367
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5295.101562, iou_loss = 0.000000, total_loss = 5295.101562
#  total_bbox = 98, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.442514), count: 3, class_loss = 309.449982, iou_loss = 2.972931, total_loss = 312.422913
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.249118), count: 1, class_loss = 1181.129272, iou_loss = 0.979004, total_loss = 1182.108276
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5342.926270, iou_loss = 0.000000, total_loss = 5342.926270
#  total_bbox = 102, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.340280), count: 3, class_loss = 309.460571, iou_loss = 0.748962, total_loss = 310.209534
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1183.113647, iou_loss = 0.000000, total_loss = 1183.113647
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5327.083008, iou_loss = 0.000000, total_loss = 5327.083008
#  total_bbox = 105, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.226528), count: 2, class_loss = 308.165863, iou_loss = 1.497742, total_loss = 309.663605
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.373967), count: 2, class_loss = 1176.773682, iou_loss = 1.645386, total_loss = 1178.419067
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5317.126953, iou_loss = 0.000000, total_loss = 5317.126953
#  total_bbox = 109, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.353764), count: 4, class_loss = 309.068939, iou_loss = 1.707703, total_loss = 310.776642
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1178.541992, iou_loss = 0.000000, total_loss = 1178.541992
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5247.808105, iou_loss = 0.000000, total_loss = 5247.808105
#  total_bbox = 113, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.303897), count: 4, class_loss = 309.333221, iou_loss = 1.748077, total_loss = 311.081299
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1178.104858, iou_loss = 0.000000, total_loss = 1178.104858
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5338.811035, iou_loss = 0.000000, total_loss = 5338.811035
#  total_bbox = 117, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.239503), count: 4, class_loss = 308.750458, iou_loss = 1.980682, total_loss = 310.731140
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1173.749268, iou_loss = 0.000000, total_loss = 1173.749268
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5278.053711, iou_loss = 0.000000, total_loss = 5278.053711
#  total_bbox = 121, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.263699), count: 3, class_loss = 309.199402, iou_loss = 2.354919, total_loss = 311.554321
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.161233), count: 1, class_loss = 1176.978271, iou_loss = 1.850220, total_loss = 1178.828491
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5267.545410, iou_loss = 0.000000, total_loss = 5267.545410
#  total_bbox = 125, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.428019), count: 6, class_loss = 308.793823, iou_loss = 2.363708, total_loss = 311.157532
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1183.777710, iou_loss = 0.000000, total_loss = 1183.777710
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5319.756348, iou_loss = 0.000000, total_loss = 5319.756348
#  total_bbox = 131, rewritten_bbox = 0.000000 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
#
#  2: 2264.781982, 2269.770264 avg loss, 0.000000 rate, 9.551985 seconds, 128 images, 5.326173 hours left
# Loaded: 0.000079 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.449884), count: 2, class_loss = 308.747528, iou_loss = 1.145844, total_loss = 309.893372
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.336574), count: 3, class_loss = 1184.139771, iou_loss = 3.220581, total_loss = 1187.360352
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5351.324707, iou_loss = 0.000000, total_loss = 5351.324707
#  total_bbox = 136, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.403990), count: 4, class_loss = 308.210571, iou_loss = 1.209015, total_loss = 309.419586
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1179.846680, iou_loss = 0.000000, total_loss = 1179.846680
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5303.772461, iou_loss = 0.000000, total_loss = 5303.772461
#  total_bbox = 140, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.229607), count: 4, class_loss = 309.168213, iou_loss = 3.835052, total_loss = 313.003265
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1181.963989, iou_loss = 0.000000, total_loss = 1181.963989
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5283.518066, iou_loss = 0.000000, total_loss = 5283.518066
#  total_bbox = 144, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.354207), count: 3, class_loss = 309.550171, iou_loss = 2.348938, total_loss = 311.899109
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.133402), count: 1, class_loss = 1181.372559, iou_loss = 1.551392, total_loss = 1182.923950
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5306.355469, iou_loss = 0.000000, total_loss = 5306.355469
#  total_bbox = 148, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.314651), count: 4, class_loss = 309.645752, iou_loss = 1.207092, total_loss = 310.852844
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1177.916016, iou_loss = 0.000000, total_loss = 1177.916016
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5326.369141, iou_loss = 0.000000, total_loss = 5326.369141
#  total_bbox = 152, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.467634), count: 3, class_loss = 309.180267, iou_loss = 1.250946, total_loss = 310.431213
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.319288), count: 3, class_loss = 1178.135986, iou_loss = 2.172241, total_loss = 1180.308228
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5279.978516, iou_loss = 0.000000, total_loss = 5279.978516
#  total_bbox = 158, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.350602), count: 5, class_loss = 309.137268, iou_loss = 4.820953, total_loss = 313.958221
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1183.162964, iou_loss = 0.000000, total_loss = 1183.162964
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5333.640137, iou_loss = 0.000000, total_loss = 5333.640137
#  total_bbox = 163, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.341388), count: 4, class_loss = 307.973633, iou_loss = 1.767303, total_loss = 309.740936
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1179.809448, iou_loss = 0.000000, total_loss = 1179.809448
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5336.683105, iou_loss = 0.000000, total_loss = 5336.683105
#  total_bbox = 167, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.494260), count: 4, class_loss = 308.649200, iou_loss = 0.588501, total_loss = 309.237701
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1178.094849, iou_loss = 0.000000, total_loss = 1178.094849
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5328.921875, iou_loss = 0.000000, total_loss = 5328.921875
#  total_bbox = 171, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.302215), count: 4, class_loss = 309.296661, iou_loss = 3.403717, total_loss = 312.700378
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.178288), count: 1, class_loss = 1183.519897, iou_loss = 1.008423, total_loss = 1184.528320
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.112877), count: 1, class_loss = 5331.909668, iou_loss = 2.459473, total_loss = 5334.369141
#  total_bbox = 177, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.368507), count: 4, class_loss = 308.477661, iou_loss = 1.415436, total_loss = 309.893097
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1178.639648, iou_loss = 0.000000, total_loss = 1178.639648
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5334.593262, iou_loss = 0.000000, total_loss = 5334.593262
#  total_bbox = 181, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.235976), count: 4, class_loss = 309.489624, iou_loss = 3.811676, total_loss = 313.301300
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1184.891479, iou_loss = 0.000000, total_loss = 1184.891479
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5322.236328, iou_loss = 0.000000, total_loss = 5322.236328
#  total_bbox = 185, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.369894), count: 4, class_loss = 309.471863, iou_loss = 1.593567, total_loss = 311.065430
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1179.242432, iou_loss = 0.000000, total_loss = 1179.242432
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5298.876465, iou_loss = 0.000000, total_loss = 5298.876465
#  total_bbox = 189, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.233157), count: 3, class_loss = 309.538361, iou_loss = 1.979950, total_loss = 311.518311
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.434497), count: 1, class_loss = 1181.912598, iou_loss = 0.466675, total_loss = 1182.379272
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.122056), count: 1, class_loss = 5335.532715, iou_loss = 2.344238, total_loss = 5337.876953
#  total_bbox = 194, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.431593), count: 4, class_loss = 308.947968, iou_loss = 2.786591, total_loss = 311.734558
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1179.374268, iou_loss = 0.000000, total_loss = 1179.374268
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5297.937988, iou_loss = 0.000000, total_loss = 5297.937988
#  total_bbox = 198, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.418987), count: 5, class_loss = 308.832916, iou_loss = 1.637909, total_loss = 310.470825
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1180.109253, iou_loss = 0.000000, total_loss = 1180.109253
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5284.020508, iou_loss = 0.000000, total_loss = 5284.020508
#  total_bbox = 203, rewritten_bbox = 0.000000 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
#
#  3: 2269.586182, 2269.751953 avg loss, 0.000000 rate, 9.656294 seconds, 192 images, 5.325926 hours left
# Loaded: 0.000060 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.338980), count: 4, class_loss = 309.757050, iou_loss = 2.180939, total_loss = 311.937988
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1180.562744, iou_loss = 0.000000, total_loss = 1180.562744
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5309.518066, iou_loss = 0.000000, total_loss = 5309.518066
#  total_bbox = 207, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.288385), count: 2, class_loss = 309.297882, iou_loss = 1.101959, total_loss = 310.399841
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.562189), count: 1, class_loss = 1182.959961, iou_loss = 0.171509, total_loss = 1183.131470
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5323.854004, iou_loss = 0.000000, total_loss = 5323.854004
#  total_bbox = 210, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.263853), count: 3, class_loss = 309.626495, iou_loss = 1.241486, total_loss = 310.867981
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.514350), count: 1, class_loss = 1178.020752, iou_loss = 0.217651, total_loss = 1178.238403
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5299.993652, iou_loss = 0.000000, total_loss = 5299.993652
#  total_bbox = 214, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.357176), count: 5, class_loss = 308.017334, iou_loss = 2.881470, total_loss = 310.898804
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1179.205688, iou_loss = 0.000000, total_loss = 1179.205688
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5314.712891, iou_loss = 0.000000, total_loss = 5314.712891
#  total_bbox = 219, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.335180), count: 4, class_loss = 309.047089, iou_loss = 2.626556, total_loss = 311.673645
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1177.431396, iou_loss = 0.000000, total_loss = 1177.431396
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5313.448242, iou_loss = 0.000000, total_loss = 5313.448242
#  total_bbox = 223, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.363285), count: 3, class_loss = 309.548157, iou_loss = 1.329712, total_loss = 310.877869
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.569443), count: 1, class_loss = 1181.605713, iou_loss = 0.128296, total_loss = 1181.734009
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5329.436523, iou_loss = 0.000000, total_loss = 5329.436523
#  total_bbox = 227, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.268234), count: 5, class_loss = 309.810303, iou_loss = 4.132721, total_loss = 313.943024
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1177.634033, iou_loss = 0.000000, total_loss = 1177.634033
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5336.135742, iou_loss = 0.000000, total_loss = 5336.135742
#  total_bbox = 232, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.279561), count: 4, class_loss = 309.210205, iou_loss = 2.174469, total_loss = 311.384674
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1180.254150, iou_loss = 0.000000, total_loss = 1180.254150
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5294.668457, iou_loss = 0.000000, total_loss = 5294.668457
#  total_bbox = 236, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.478914), count: 5, class_loss = 309.253326, iou_loss = 2.824066, total_loss = 312.077393
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1179.792969, iou_loss = 0.000000, total_loss = 1179.792969
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5301.106934, iou_loss = 0.000000, total_loss = 5301.106934
#  total_bbox = 241, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.396392), count: 4, class_loss = 308.791962, iou_loss = 2.339478, total_loss = 311.131439
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1177.406250, iou_loss = 0.000000, total_loss = 1177.406250
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5270.410645, iou_loss = 0.000000, total_loss = 5270.410645
#  total_bbox = 245, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.324963), count: 4, class_loss = 309.621185, iou_loss = 1.768677, total_loss = 311.389862
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1181.348755, iou_loss = 0.000000, total_loss = 1181.348755
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5305.484863, iou_loss = 0.000000, total_loss = 5305.484863
#  total_bbox = 249, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.504748), count: 4, class_loss = 308.765289, iou_loss = 0.667297, total_loss = 309.432587
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1179.826172, iou_loss = 0.000000, total_loss = 1179.826172
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5315.370117, iou_loss = 0.000000, total_loss = 5315.370117
#  total_bbox = 253, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.175461), count: 4, class_loss = 308.777679, iou_loss = 4.326630, total_loss = 313.104309
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1178.674194, iou_loss = 0.000000, total_loss = 1178.674194
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5327.496582, iou_loss = 0.000000, total_loss = 5327.496582
#  total_bbox = 257, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.375099), count: 4, class_loss = 309.889130, iou_loss = 1.026489, total_loss = 310.915619
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1183.893433, iou_loss = 0.000000, total_loss = 1183.893433
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5333.592285, iou_loss = 0.000000, total_loss = 5333.592285
#  total_bbox = 261, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.236343), count: 4, class_loss = 309.591858, iou_loss = 4.426727, total_loss = 314.018585
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1181.891846, iou_loss = 0.000000, total_loss = 1181.891846
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5328.615723, iou_loss = 0.000000, total_loss = 5328.615723
#  total_bbox = 265, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.383897), count: 4, class_loss = 309.046539, iou_loss = 2.267731, total_loss = 311.314270
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1179.843018, iou_loss = 0.000000, total_loss = 1179.843018
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 5297.533691, iou_loss = 0.000000, total_loss = 5297.533691
#  total_bbox = 269, rewritten_bbox = 0.000000 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
#
#  4: 2268.075439, 2269.584229 avg loss, 0.000000 rate, 9.821244 seconds, 256 images, 5.326232 hours left
# Loaded: 0.000075 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.328462), count: 5, class_loss = 309.484131, iou_loss = 3.585541, total_loss = 313.069672
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.434454), count: 1, class_loss = 1183.445923, iou_loss = 0.192383, total_loss = 1183.638306
# ^C

# %% [markdown]
# ## *Continue training from where you left*
# Continue training from where you left off, your Model training can be stopped due to multiple reasons, like the notebook time out, notebook craches, due to network issues,  and many more,  so you can start your training from where you left off, by passing the previous trained weights.

# %%
# !./darknet detector train /content/gdrive/MyDrive/custom_data/detector.data /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg /content/gdrive/MyDrive/custom_data/backup/yolov3-custom_4000.weights -dont_show
# Out:
#  CUDA-version: 11020 (11020), cuDNN: 8.1.1, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# yolov3-custom
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv     18       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  18 0.006 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv     18       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  18 0.012 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#   98 route  97 36 	                           ->   52 x  52 x 384
#   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
#  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  105 conv     18       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x  18 0.025 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 65.304
# avg_outputs = 516723
#  Allocate additional workspace_size = 149.82 MB
# Loading weights from /content/gdrive/MyDrive/custom_data/backup/yolov3-custom_4000.weights...
#  seen 64, trained: 256 K-images (4 Kilo-batches_64)
# Done! Loaded 20 layers from weights-file
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# Resizing, random_coef = 1.40
#
#  608 x 608
#  Create 6 permanent cpu-threads
#  try to allocate additional workspace_size = 144.50 MB
#  CUDA allocate done!
# Loaded: 0.000052 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.482595), count: 5, class_loss = 256.133331, iou_loss = 3.834686, total_loss = 259.968018
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1228.973389, iou_loss = 0.000000, total_loss = 1228.973389
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4422.851562, iou_loss = 0.000000, total_loss = 4422.851562
#  total_bbox = 5, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.572757), count: 3, class_loss = 257.285675, iou_loss = 0.707397, total_loss = 257.993073
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.407004), count: 1, class_loss = 1237.039062, iou_loss = 0.272949, total_loss = 1237.312012
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4404.664551, iou_loss = 0.000000, total_loss = 4404.664551
#  total_bbox = 9, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.159621), count: 3, class_loss = 258.132111, iou_loss = 1.828094, total_loss = 259.960205
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1235.148804, iou_loss = 0.000000, total_loss = 1235.148804
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.354757), count: 1, class_loss = 4407.683594, iou_loss = 0.577637, total_loss = 4408.261230
#  total_bbox = 13, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.195529), count: 4, class_loss = 258.211670, iou_loss = 3.923401, total_loss = 262.135071
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1239.837280, iou_loss = 0.000000, total_loss = 1239.837280
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4413.361328, iou_loss = 0.000000, total_loss = 4413.361328
#  total_bbox = 17, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.305514), count: 5, class_loss = 254.485519, iou_loss = 1.866898, total_loss = 256.352417
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1226.371338, iou_loss = 0.000000, total_loss = 1226.371338
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4398.892090, iou_loss = 0.000000, total_loss = 4398.892090
#  total_bbox = 22, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.339635), count: 4, class_loss = 257.278809, iou_loss = 1.252136, total_loss = 258.530945
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1242.113159, iou_loss = 0.000000, total_loss = 1242.113159
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4415.069824, iou_loss = 0.000000, total_loss = 4415.069824
#  total_bbox = 25, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.462979), count: 3, class_loss = 255.802856, iou_loss = 0.752808, total_loss = 256.555664
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.482139), count: 1, class_loss = 1229.405396, iou_loss = 0.229004, total_loss = 1229.634399
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4389.430664, iou_loss = 0.000000, total_loss = 4389.430664
#  total_bbox = 29, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.405966), count: 3, class_loss = 256.615845, iou_loss = 1.505280, total_loss = 258.121124
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.358084), count: 2, class_loss = 1240.843994, iou_loss = 1.332031, total_loss = 1242.176025
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4412.270020, iou_loss = 0.000000, total_loss = 4412.270020
#  total_bbox = 34, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.289873), count: 2, class_loss = 256.402313, iou_loss = 0.733154, total_loss = 257.135468
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.572787), count: 2, class_loss = 1235.630371, iou_loss = 0.521973, total_loss = 1236.152344
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4404.791992, iou_loss = 0.000000, total_loss = 4404.791992
#  total_bbox = 38, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.331322), count: 3, class_loss = 255.976593, iou_loss = 2.012238, total_loss = 257.988831
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.300991), count: 1, class_loss = 1234.037598, iou_loss = 0.681396, total_loss = 1234.718994
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4395.157227, iou_loss = 0.000000, total_loss = 4395.157227
#  total_bbox = 42, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.558144), count: 3, class_loss = 257.393066, iou_loss = 0.581909, total_loss = 257.974976
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.045222), count: 1, class_loss = 1240.567017, iou_loss = 3.135010, total_loss = 1243.702026
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4432.377441, iou_loss = 0.000000, total_loss = 4432.377441
#  total_bbox = 46, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.364752), count: 4, class_loss = 256.385040, iou_loss = 1.677765, total_loss = 258.062805
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1226.473389, iou_loss = 0.000000, total_loss = 1226.473389
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4401.999512, iou_loss = 0.000000, total_loss = 4401.999512
#  total_bbox = 50, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.397976), count: 4, class_loss = 256.059998, iou_loss = 7.673828, total_loss = 263.733826
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1233.490479, iou_loss = 0.000000, total_loss = 1233.490479
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4388.077148, iou_loss = 0.000000, total_loss = 4388.077148
#  total_bbox = 54, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.202908), count: 4, class_loss = 257.861023, iou_loss = 4.180115, total_loss = 262.041138
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 1210.631104, iou_loss = 0.000000, total_loss = 1210.631104
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4388.408691, iou_loss = 0.000000, total_loss = 4388.408691
#  total_bbox = 58, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.389128), count: 3, class_loss = 256.548767, iou_loss = 0.798645, total_loss = 257.347412
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.491101), count: 1, class_loss = 1232.925049, iou_loss = 0.188110, total_loss = 1233.113159
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4400.439453, iou_loss = 0.000000, total_loss = 4400.439453
#  total_bbox = 62, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.243250), count: 2, class_loss = 256.313507, iou_loss = 2.522797, total_loss = 258.836304
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.137828), count: 2, class_loss = 1234.935669, iou_loss = 7.603394, total_loss = 1242.539062
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 4413.863281, iou_loss = 0.000000, total_loss = 4413.863281
#  total_bbox = 66, rewritten_bbox = 0.000000 %
#
#  Tensor Cores are used.
#
#  4001: 1966.146484, 1966.146484 avg loss, 0.000100 rate, 9.037081 seconds, 256064 images, -1.000000 hours left
# Loaded: 0.000105 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.412046), count: 4, class_loss = 27.668461, iou_loss = 2.807924, total_loss = 30.476385
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 10.741959, iou_loss = 0.000000, total_loss = 10.741959
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.060147, iou_loss = 0.000000, total_loss = 0.060147
#  total_bbox = 70, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.263905), count: 3, class_loss = 29.394304, iou_loss = 2.808321, total_loss = 32.202625
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.256973), count: 1, class_loss = 10.870669, iou_loss = 1.022382, total_loss = 11.893051
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.058148, iou_loss = 0.000000, total_loss = 0.058148
#  total_bbox = 74, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.400927), count: 4, class_loss = 29.976412, iou_loss = 3.191771, total_loss = 33.168182
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 14.008018, iou_loss = 0.000000, total_loss = 14.008018
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.124196, iou_loss = 0.000000, total_loss = 0.124196
#  total_bbox = 78, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.170496), count: 7, class_loss = 33.845032, iou_loss = 13.397518, total_loss = 47.242550
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 13.811959, iou_loss = 0.000000, total_loss = 13.811959
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.127636, iou_loss = 0.000000, total_loss = 0.127636
#  total_bbox = 85, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.433059), count: 3, class_loss = 30.860851, iou_loss = 0.502453, total_loss = 31.363304
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.041710), count: 2, class_loss = 15.490963, iou_loss = 8.625040, total_loss = 24.116003
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.130172, iou_loss = 0.000000, total_loss = 0.130172
#  total_bbox = 90, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.505217), count: 4, class_loss = 30.329733, iou_loss = 0.645544, total_loss = 30.975277
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 13.005600, iou_loss = 0.000000, total_loss = 13.005600
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.105538, iou_loss = 0.000000, total_loss = 0.105538
#  total_bbox = 94, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.365846), count: 4, class_loss = 28.252342, iou_loss = 1.800472, total_loss = 30.052814
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 9.842005, iou_loss = 0.000000, total_loss = 9.842005
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.056039, iou_loss = 0.000000, total_loss = 0.056039
#  total_bbox = 98, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.349336), count: 4, class_loss = 29.924387, iou_loss = 0.827097, total_loss = 30.751484
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 11.620870, iou_loss = 0.000000, total_loss = 11.620870
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.076240, iou_loss = 0.000000, total_loss = 0.076240
#  total_bbox = 102, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.371331), count: 5, class_loss = 27.498295, iou_loss = 3.033270, total_loss = 30.531565
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.298903), count: 1, class_loss = 11.888594, iou_loss = 0.418211, total_loss = 12.306805
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.369950), count: 1, class_loss = 0.468899, iou_loss = 0.368362, total_loss = 0.837261
#  total_bbox = 109, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.341693), count: 9, class_loss = 27.323864, iou_loss = 8.379978, total_loss = 35.703842
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 9.356630, iou_loss = 0.000000, total_loss = 9.356630
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.049068, iou_loss = 0.000000, total_loss = 0.049068
#  total_bbox = 118, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.326276), count: 3, class_loss = 25.822224, iou_loss = 0.968670, total_loss = 26.790894
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.007797), count: 1, class_loss = 9.834648, iou_loss = 6.967314, total_loss = 16.801962
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.050590, iou_loss = 0.000000, total_loss = 0.050590
#  total_bbox = 122, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.341865), count: 4, class_loss = 26.572351, iou_loss = 0.891304, total_loss = 27.463655
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 12.250985, iou_loss = 0.000000, total_loss = 12.250985
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.094499, iou_loss = 0.000000, total_loss = 0.094499
#  total_bbox = 126, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.471007), count: 7, class_loss = 26.830458, iou_loss = 2.231285, total_loss = 29.061743
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 8.042784, iou_loss = 0.000000, total_loss = 8.042784
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.050877, iou_loss = 0.000000, total_loss = 0.050877
#  total_bbox = 133, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.234208), count: 3, class_loss = 25.232931, iou_loss = 1.488609, total_loss = 26.721540
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.076179), count: 1, class_loss = 9.106160, iou_loss = 2.747182, total_loss = 11.853342
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.053743, iou_loss = 0.000000, total_loss = 0.053743
#  total_bbox = 137, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.424951), count: 4, class_loss = 25.642653, iou_loss = 2.048096, total_loss = 27.690748
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.372666), count: 4, class_loss = 9.574137, iou_loss = 2.514481, total_loss = 12.088617
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.037180, iou_loss = 0.000000, total_loss = 0.037180
#  total_bbox = 145, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.315033), count: 4, class_loss = 30.351265, iou_loss = 1.708954, total_loss = 32.060219
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 14.778795, iou_loss = 0.000000, total_loss = 14.778795
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.132614, iou_loss = 0.000000, total_loss = 0.132614
#  total_bbox = 149, rewritten_bbox = 0.000000 %
#
#  Tensor Cores are used.
#
#  4002: 14.808754, 1771.012695 avg loss, 0.000100 rate, 8.932253 seconds, 256128 images, 2.507807 hours left
# Loaded: 0.000088 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.358410), count: 4, class_loss = 1.547313, iou_loss = 1.532219, total_loss = 3.079532
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.002119, iou_loss = 0.000000, total_loss = 0.002119
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
#  total_bbox = 153, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.184046), count: 4, class_loss = 1.581157, iou_loss = 2.677340, total_loss = 4.258497
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001334, iou_loss = 0.000000, total_loss = 0.001334
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 157, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.435742), count: 4, class_loss = 1.598147, iou_loss = 1.120569, total_loss = 2.718716
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001821, iou_loss = 0.000000, total_loss = 0.001821
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 161, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.343580), count: 4, class_loss = 1.551470, iou_loss = 2.042358, total_loss = 3.593828
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.002893, iou_loss = 0.000000, total_loss = 0.002893
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
#  total_bbox = 165, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.357288), count: 4, class_loss = 1.566451, iou_loss = 1.401942, total_loss = 2.968393
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001366, iou_loss = 0.000000, total_loss = 0.001366
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 169, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.367392), count: 3, class_loss = 1.168349, iou_loss = 0.935483, total_loss = 2.103831
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.669002), count: 1, class_loss = 0.284640, iou_loss = 0.088292, total_loss = 0.372932
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 173, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.572865), count: 4, class_loss = 1.443624, iou_loss = 0.745017, total_loss = 2.188641
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001040, iou_loss = 0.000000, total_loss = 0.001040
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 177, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.444819), count: 4, class_loss = 1.699800, iou_loss = 1.035485, total_loss = 2.735285
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.002223, iou_loss = 0.000000, total_loss = 0.002223
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
#  total_bbox = 181, rewritten_bbox = 0.000000 %
# ^C

# %% [markdown]
# # **Step 12**
# ## *Calculating Mean average precision of Specific Weights*
# As we have trained our weights up to 2000 epochs, we will calculate the mean average precision of our trained weights.

# %%
# !./darknet detector map /content/gdrive/MyDrive/custom_data/detector.data /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg /content/gdrive/MyDrive/custom_data/backup/yolov3-custom_2000.weights -dont_show
# Out:
#  CUDA-version: 11020 (11020), cuDNN: 8.1.1, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv     18       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  18 0.006 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv     18       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  18 0.012 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#   98 route  97 36 	                           ->   52 x  52 x 384
#   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
#  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  105 conv     18       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x  18 0.025 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 65.304
# avg_outputs = 516723
#  Allocate additional workspace_size = 52.44 MB
# Loading weights from /content/gdrive/MyDrive/custom_data/backup/yolov3-custom_4000.weights...
#  seen 64, trained: 256 K-images (4 Kilo-batches_64)
# Done! Loaded 20 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# 24^C
